# %%
# %load Stark-main/tracking/train.py
import os
import argparse


def parse_args():
    """
    args for training.
    """
    parser = argparse.ArgumentParser(description='Parse args for training')
    # for train
    parser.add_argument('--script', type=str, help='training script name')
    parser.add_argument('--config', type=str, default='baseline', help='yaml configure file name')
    parser.add_argument('--save_dir', type=str, help='root directory to save checkpoints, logs, and tensorboard')
    parser.add_argument('--mode', type=str, choices=["single", "multiple"], default="multiple",
                        help="train on single gpu or multiple gpus")
    parser.add_argument('--nproc_per_node', type=int, help="number of GPUs per node")  # specify when mode is multiple
    parser.add_argument('--use_lmdb', type=int, choices=[0, 1], default=0)  # whether datasets are in lmdb format
    parser.add_argument('--script_prv', type=str, help='training script name')
    parser.add_argument('--config_prv', type=str, default='baseline', help='yaml configure file name')
    # for knowledge distillation
    parser.add_argument('--distill', type=int, choices=[0, 1], default=0)  # whether to use knowledge distillation
    parser.add_argument('--script_teacher', type=str, help='teacher script name')
    parser.add_argument('--config_teacher', type=str, help='teacher yaml configure file name')

    args = parser.parse_args()

    return args


def main():
    args = parse_args()
    if args.mode == "single":
        train_cmd = "python Stark-main/lib/train/run_training.py --script %s --config %s --save_dir %s --use_lmdb %d " \
                    "--script_prv %s --config_prv %s --distill %d --script_teacher %s --config_teacher %s" \
                    % (args.script, args.config, args.save_dir, args.use_lmdb, args.script_prv, args.config_prv,
                       args.distill, args.script_teacher, args.config_teacher)
    elif args.mode == "multiple":
        train_cmd = "python -m torch.distributed.launch --nproc_per_node %d Stark-main/lib/train/run_training.py " \
                    "--script %s --config %s --save_dir %s --use_lmdb %d --script_prv %s --config_prv %s  " \
                    "--distill %d --script_teacher %s --config_teacher %s" \
                    % (args.nproc_per_node, args.script, args.config, args.save_dir, args.use_lmdb, args.script_prv,
                       args.config_prv, args.distill, args.script_teacher, args.config_teacher)
    else:
        raise ValueError("mode should be 'single' or 'multiple'.")
    os.system(train_cmd)


if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--script SCRIPT] [--config CONFIG]
#                              [--save_dir SAVE_DIR] [--mode {single,multiple}]
#                              [--nproc_per_node NPROC_PER_NODE]
#                              [--use_lmdb {0,1}] [--script_prv SCRIPT_PRV]
#                              [--config_prv CONFIG_PRV] [--distill {0,1}]
#                              [--script_teacher SCRIPT_TEACHER]
#                              [--config_teacher CONFIG_TEACHER]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\stony\AppData\Roaming\jupyter\runtime\kernel-06998603-9621-42ce-9eeb-f3ecb77a9afc.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# STARK-S50
# !python Stark-main/tracking/train.py --script stark_s --config baseline --save_dir . --mode multiple --nproc_per_node 8
# Out:
# NOTE: Redirects are currently not supported in Windows or MacOs.
# C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# C:\Users\stony\anaconda3\envs\pytorch\python.exe: can't open file 'lib/train/run_training.py': [Errno 2] No such file or directory
# ERROR:torch.distributed.elastic.multiprocessing.api:failed (exitcode: 2) local_rank: 0 (pid: 23700) of binary: C:\Users\stony\anaconda3\envs\pytorch\python.exe
# Traceback (most recent call last):
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\launch.py", line 193, in <module>
#     main()
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\launch.py", line 189, in main
#     launch(args)
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\launch.py", line 174, in launch
#     run(args)
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\run.py", line 713, in run
#     )(*cmd_args)
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\launcher\api.py", line 131, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "C:\Users\stony\anaconda3\envs\pytorch\lib\site-packages\torch\distributed\launcher\api.py", line 261, in launch_agent
#     failures=result.failures,
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# lib/train/run_training.py FAILED
# ------------------------------------------------------------
# Failures:
# [1]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 1 (local_rank: 1)
#   exitcode  : 2 (pid: 1048)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [2]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 2 (local_rank: 2)
#   exitcode  : 2 (pid: 12576)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [3]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 3 (local_rank: 3)
#   exitcode  : 2 (pid: 23620)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [4]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 4 (local_rank: 4)
#   exitcode  : 2 (pid: 27500)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [5]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 5 (local_rank: 5)
#   exitcode  : 2 (pid: 30612)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [6]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 6 (local_rank: 6)
#   exitcode  : 2 (pid: 18464)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [7]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 7 (local_rank: 7)
#   exitcode  : 2 (pid: 21644)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2022-04-23_19:30:07
#   host      : DESKTOP-D14BGO7.cable.rcn.com
#   rank      : 0 (local_rank: 0)
#   exitcode  : 2 (pid: 23700)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================
